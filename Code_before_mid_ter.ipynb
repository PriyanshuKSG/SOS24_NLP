# %%
# !pip install -U sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 1.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('moka-ai/m3e-base')
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/26.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/932 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/409M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
sentences = [
    "man", "father", "woman", "mother"
]

embeddings = model.encode(sentences)

# %%
print(type(embeddings))
print(embeddings.shape)
print(embeddings[0][:10])
# Out:
# <class 'numpy.ndarray'>
# (4, 768)
# [ 1.055717    0.45726714  0.786356    0.15908512 -0.09313009 -0.4680747
#  -0.30403635  0.46772513 -1.2759916  -0.04360369]

# %%
similarities = cosine_similarity(embeddings)
similarities.shape
# Out:
# (4, 4)

# %%
for i in range(len(sentences)):
  for j in range(len(sentences)):
    if i != j:
      print(f"{sentences[i]} <-> {sentences[j]} : {similarities[i][j]}")
# Out:
# man <-> father : 0.7639422416687012
# man <-> woman : 0.7832493782043457
# man <-> mother : 0.7292754054069519
# father <-> man : 0.7639422416687012
# father <-> woman : 0.7072820663452148
# father <-> mother : 0.8740250468254089
# woman <-> man : 0.7832493782043457
# woman <-> father : 0.7072820663452148
# woman <-> mother : 0.7807108163833618
# mother <-> man : 0.7292754054069519
# mother <-> father : 0.8740250468254089
# mother <-> woman : 0.7807108163833618

# %%
import nltk
from nltk.stem.porter import PorterStemmer

p_stemmer = PorterStemmer()

# %%
words = ['run', 'ran', 'running', 'easy', 'easier', 'easily', 'fairly']

for word in words:
    print(word, " --> ", p_stemmer.stem(word))
# Out:
# run  -->  run
# ran  -->  ran
# running  -->  run
# easy  -->  easi
# easier  -->  easier
# easily  -->  easili
# fairly  -->  fairli

# %%
from nltk.stem.snowball import SnowballStemmer

s_stemmer = SnowballStemmer(language = "english")

# %%
for word in words:
    print(word, " --> ", s_stemmer.stem(word))
# Out:
# run  -->  run
# ran  -->  ran
# running  -->  run
# easy  -->  easi
# easier  -->  easier
# easily  -->  easili
# fairly  -->  fair

# %%
text = "The Quick Brown Fox jumps Over! lazy dogs: isn't it amazing? Yes, absolutely; I can't believe it happened—yesterday! Surprisingly, nobody noticed... What a sight!"
text
# Out:
# "The Quick Brown Fox jumps Over! lazy dogs: isn't it amazing? Yes, absolutely; I can't believe it happened—yesterday! Surprisingly, nobody noticed... What a sight!"

# %%
import re

clean_text = re.sub(r'[^\w\s]', '', text)
clean_text
# Out:
# 'The Quick Brown Fox jumps Over lazy dogs isnt it amazing Yes absolutely I cant believe it happenedyesterday Surprisingly nobody noticed What a sight'

# %%
token_list = clean_text.split()
print(len(token_list))
# Out:
# 24

# %%
token_list[:5]
# Out:
# ['The', 'Quick', 'Brown', 'Fox', 'jumps']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

docs = [
    "I love chocolate ice cream",
    "Chocolate ice cream is my favorite",
    "I love milk"
]

vectorizer = TfidfVectorizer()

# %%
tfidf_matrix = vectorizer.fit_transform(docs)
feature_names = vectorizer.get_feature_names_out()

# %%
tfidf_matrix.shape
# Out:
# (3, 8)

# %%
tfidf_matrix.todense()
# Out:
# matrix([[0.5       , 0.5       , 0.        , 0.5       , 0.        ,
#          0.5       , 0.        , 0.        ],
#         [0.34949812, 0.34949812, 0.45954803, 0.34949812, 0.45954803,
#          0.        , 0.        , 0.45954803],
#         [0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.60534851, 0.79596054, 0.        ]])
